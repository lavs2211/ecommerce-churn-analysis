# %%
import pandas as pd

# Load the original messy dataset
file_path = "https://d.docs.live.net/ddcaa35f9fe89d70/Desktop/lavanya/online%5eMretail/Online%20Retail.xlsx"
df = pd.read_excel(file_path, engine='openpyxl')
